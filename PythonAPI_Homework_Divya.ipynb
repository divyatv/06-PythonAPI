# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Your final notebook must:

# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save both a CSV of all data retrieved and png images for each scatter plot.

# As final considerations:

# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# * See [Example Solution](WeatherPy_Example.pdf) for a reference on expected format.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


##Divyas imports
import json
from pandas.io.json import json_normalize

# Import API key
from api_keys import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

#print(lat_lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #print(city)
    #print(lat_lng)
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

        
        
#print(cities)   

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=London
#Perform a weather check on each city using a series of successive API calls.
############################################################################################
## Build the API urls
baseurl="http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
###########################################################################################
#target_url="http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=London"
# humidity=[]
# temperature=[]
# cloudiness=[]
# windspeed=[]
latitude=[]
# longitude=[]
# country=[]
# max_temp=[]
# date=[]

# try:
#     students["Jezebel"]
# except KeyError:
#     print("Oops, that key doesn't exist.")
# with open(api_response, mode='w', encoding='utf-8') as f:
#     json.dump([], f)
###########################################################################################
#### Call the API and write the output into a JSON file for further calculations
#### Split the calls for 50 cities at once and then sleep for 30 secs to make sure limit 
#### doesnt exceed.
#### print target url and Set number 
###########################################################################################
reponsefull=[]

for i in range(0, len(cities)):
    target_url= baseurl+ "appid=" + api_key + "&units=" + units +"&q=" + cities[i]
    print("target_url=", target_url)
    Set = i/50
    try:
        response=(requests.get(target_url).json())
        with open("api_response.json", mode='w', encoding='utf-8') as f:
            reponsefull.append(response)
            json.dump(reponsefull, f)
        latitude.append(response['coord']['lat'])
#         longitude.append(response['coord']['lon'])
#         temperature.append(response['main']['temp'])
#         humidity.append(response['main']['humidity'])
#         cloudiness.append(response['clouds']['all'])
#         windspeed.append(response['wind']['speed'])
#         country.append(response['sys']['country'])
#         max_temp.append(response['main']['temp_max'])
#         date.append(response['dt'])
        #vowels.index('e')
        city=city
        index=cities.index(city)
        print('Processing Record', i , 'of Set', round(Set, 0),' |',  cities[i])
    except KeyError as error: 
#         cities=cities.remove(city)
        #print(f'{city} not found with error:{error}. Skipping ...')
        print(cities[i], "not found.Skipping ...")
################## SLEEP after 50 cities to make sure you dont exceed the api call limit #########################################################################        
    if (i >50):
        if (i//50 == 0):
            time.sleep(30)   
 
print("cities length",len(cities))
print(cities)

###########################################################################################
### Doc reference #########################################################################
#df = pd.DataFrame.from_dict(json_normalize(data), orient='columns') -- json to dataframe for nested dict

#weatherdf=pd.DataFrame.from_dict(json_normalize())

##################
# with open('response.txt', 'w') as outfile:  
#     json.dump(output_data_file, outfile)
# Out:
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=taolanaro
# taolanaro not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=jamestown
# Processing Record 1 of Set 0.0  | jamestown
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sao filipe
# Processing Record 2 of Set 0.0  | sao filipe
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=geraldton
# Processing Record 3 of Set 0.0  | geraldton
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=east london
# Processing Record 4 of Set 0.0  | east london
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=atuona
# Processing Record 5 of Set 0.0  | atuona
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=airai
# Processing Record 6 of Set 0.0  | airai
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=belushya guba
# belushya guba not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=punta arenas
# Processing Record 8 of Set 0.0  | punta arenas
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kruisfontein
# Processing Record 9 of Set 0.0  | kruisfontein
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tsihombe
# tsihombe not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=svetlogorsk
# Processing Record 11 of Set 0.0  | svetlogorsk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=darnah
# Processing Record 12 of Set 0.0  | darnah
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=torbay
# Processing Record 13 of Set 0.0  | torbay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=busselton
# Processing Record 14 of Set 0.0  | busselton
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=touros
# Processing Record 15 of Set 0.0  | touros
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=zhicheng
# Processing Record 16 of Set 0.0  | zhicheng
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=rikitea
# Processing Record 17 of Set 0.0  | rikitea
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=awbari
# Processing Record 18 of Set 0.0  | awbari
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=montepuez
# Processing Record 19 of Set 0.0  | montepuez
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=port alfred
# Processing Record 20 of Set 0.0  | port alfred
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ilulissat
# Processing Record 21 of Set 0.0  | ilulissat
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bredasdorp
# Processing Record 22 of Set 0.0  | bredasdorp
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=iisalmi
# Processing Record 23 of Set 0.0  | iisalmi
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kaitangata
# Processing Record 24 of Set 0.0  | kaitangata
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ayorou
# Processing Record 25 of Set 0.0  | ayorou
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mehamn
# Processing Record 26 of Set 1.0  | mehamn
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bengkulu
# bengkulu not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=duvan
# Processing Record 28 of Set 1.0  | duvan
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=muzhi
# Processing Record 29 of Set 1.0  | muzhi
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=port hardy
# Processing Record 30 of Set 1.0  | port hardy
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bandarbeyla
# Processing Record 31 of Set 1.0  | bandarbeyla
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=lebu
# Processing Record 32 of Set 1.0  | lebu
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=longyearbyen
# Processing Record 33 of Set 1.0  | longyearbyen
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ushuaia
# Processing Record 34 of Set 1.0  | ushuaia
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=lagoa
# Processing Record 35 of Set 1.0  | lagoa
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=seeboden
# Processing Record 36 of Set 1.0  | seeboden
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mutoko
# Processing Record 37 of Set 1.0  | mutoko
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=khorixas
# Processing Record 38 of Set 1.0  | khorixas
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=avarua
# Processing Record 39 of Set 1.0  | avarua
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=toamasina
# Processing Record 40 of Set 1.0  | toamasina
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=soavinandriana
# Processing Record 41 of Set 1.0  | soavinandriana
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mar del plata
# Processing Record 42 of Set 1.0  | mar del plata
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nakonde
# Processing Record 43 of Set 1.0  | nakonde
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=san patricio
# Processing Record 44 of Set 1.0  | san patricio
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=barrow
# Processing Record 45 of Set 1.0  | barrow
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=vaini
# Processing Record 46 of Set 1.0  | vaini
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kholodnyy
# Processing Record 47 of Set 1.0  | kholodnyy
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=meadow lake
# Processing Record 48 of Set 1.0  | meadow lake
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=severo-kurilsk
# Processing Record 49 of Set 1.0  | severo-kurilsk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nemuro
# Processing Record 50 of Set 1.0  | nemuro
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=half moon bay
# Processing Record 51 of Set 1.0  | half moon bay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kapaa
# Processing Record 52 of Set 1.0  | kapaa
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=santa rosa
# Processing Record 53 of Set 1.0  | santa rosa
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tasiilaq
# Processing Record 54 of Set 1.0  | tasiilaq
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=isangel
# Processing Record 55 of Set 1.0  | isangel
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=cherskiy
# Processing Record 56 of Set 1.0  | cherskiy
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=port pirie
# Processing Record 57 of Set 1.0  | port pirie
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=hobart
# Processing Record 58 of Set 1.0  | hobart
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=shyryayeve
# Processing Record 59 of Set 1.0  | shyryayeve
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=umm bab
# Processing Record 60 of Set 1.0  | umm bab
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=saint-augustin
# Processing Record 61 of Set 1.0  | saint-augustin
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=hilo
# Processing Record 62 of Set 1.0  | hilo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=skibbereen
# Processing Record 63 of Set 1.0  | skibbereen
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=souillac
# Processing Record 64 of Set 1.0  | souillac
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=thompson
# Processing Record 65 of Set 1.0  | thompson
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=alugan
# Processing Record 66 of Set 1.0  | alugan
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=puerto ayora
# Processing Record 67 of Set 1.0  | puerto ayora
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=albany
# Processing Record 68 of Set 1.0  | albany
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=vardo
# Processing Record 69 of Set 1.0  | vardo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=shubarkuduk
# Processing Record 70 of Set 1.0  | shubarkuduk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=barentsburg
# barentsburg not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=butaritari
# Processing Record 72 of Set 1.0  | butaritari
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kavaratti
# Processing Record 73 of Set 1.0  | kavaratti
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=naze
# Processing Record 74 of Set 1.0  | naze
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=atar
# Processing Record 75 of Set 2.0  | atar
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=saint george
# Processing Record 76 of Set 2.0  | saint george
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=georgetown
# Processing Record 77 of Set 2.0  | georgetown
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=new norfolk
# Processing Record 78 of Set 2.0  | new norfolk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=dikson
# Processing Record 79 of Set 2.0  | dikson
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=yemelyanovo
# Processing Record 80 of Set 2.0  | yemelyanovo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=douentza
# Processing Record 81 of Set 2.0  | douentza
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=coruripe
# Processing Record 82 of Set 2.0  | coruripe
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=staryy krym
# Processing Record 83 of Set 2.0  | staryy krym
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=saskylakh
# Processing Record 84 of Set 2.0  | saskylakh
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=cape town
# Processing Record 85 of Set 2.0  | cape town
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mataura
# Processing Record 86 of Set 2.0  | mataura
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mys shmidta
# mys shmidta not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=general roca
# Processing Record 88 of Set 2.0  | general roca
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bethel
# Processing Record 89 of Set 2.0  | bethel
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=copiapo
# Processing Record 90 of Set 2.0  | copiapo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=batemans bay
# Processing Record 91 of Set 2.0  | batemans bay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ushtobe
# Processing Record 92 of Set 2.0  | ushtobe
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bambanglipuro
# Processing Record 93 of Set 2.0  | bambanglipuro
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=santa cruz
# Processing Record 94 of Set 2.0  | santa cruz
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ust-maya
# Processing Record 95 of Set 2.0  | ust-maya
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=taywarah
# Processing Record 96 of Set 2.0  | taywarah
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=quirinopolis
# Processing Record 97 of Set 2.0  | quirinopolis
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kindersley
# Processing Record 98 of Set 2.0  | kindersley
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=vanimo
# Processing Record 99 of Set 2.0  | vanimo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=rawson
# Processing Record 100 of Set 2.0  | rawson
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mirabad
# Processing Record 101 of Set 2.0  | mirabad
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=esperance
# Processing Record 102 of Set 2.0  | esperance
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=znamenskoye
# Processing Record 103 of Set 2.0  | znamenskoye
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=castro
# Processing Record 104 of Set 2.0  | castro
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=takob
# takob not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sao jose do campestre
# Processing Record 106 of Set 2.0  | sao jose do campestre
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tabiauea
# tabiauea not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=katsuura
# Processing Record 108 of Set 2.0  | katsuura
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=norman wells
# Processing Record 109 of Set 2.0  | norman wells
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=hermanus
# Processing Record 110 of Set 2.0  | hermanus
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=qaanaaq
# Processing Record 111 of Set 2.0  | qaanaaq
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=balimo
# balimo not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=clyde river
# Processing Record 113 of Set 2.0  | clyde river
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=constitucion
# Processing Record 114 of Set 2.0  | constitucion
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=provideniya
# Processing Record 115 of Set 2.0  | provideniya
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=samusu
# samusu not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kamenskoye
# kamenskoye not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=molodizhne
# Processing Record 118 of Set 2.0  | molodizhne
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=rio gallegos
# Processing Record 119 of Set 2.0  | rio gallegos
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=chokurdakh
# Processing Record 120 of Set 2.0  | chokurdakh
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=paracuru
# Processing Record 121 of Set 2.0  | paracuru
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=zaysan
# Processing Record 122 of Set 2.0  | zaysan
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=krasnoselkup
# krasnoselkup not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=luderitz
# Processing Record 124 of Set 2.0  | luderitz
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=felidhoo
# felidhoo not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=biak
# Processing Record 126 of Set 3.0  | biak
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=imbituba
# Processing Record 127 of Set 3.0  | imbituba
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=banmo
# banmo not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=alotau
# alotau not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tessalit
# Processing Record 130 of Set 3.0  | tessalit
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=hun
# Processing Record 131 of Set 3.0  | hun
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=fortuna
# Processing Record 132 of Set 3.0  | fortuna
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sao joao da barra
# Processing Record 133 of Set 3.0  | sao joao da barra
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=isla vista
# Processing Record 134 of Set 3.0  | isla vista
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nantucket
# Processing Record 135 of Set 3.0  | nantucket
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=victor harbor
# Processing Record 136 of Set 3.0  | victor harbor
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ancud
# Processing Record 137 of Set 3.0  | ancud
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kavieng
# Processing Record 138 of Set 3.0  | kavieng
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=laguna
# Processing Record 139 of Set 3.0  | laguna
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=arraial do cabo
# Processing Record 140 of Set 3.0  | arraial do cabo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bluff
# Processing Record 141 of Set 3.0  | bluff
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=urengoy
# Processing Record 142 of Set 3.0  | urengoy
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=north platte
# Processing Record 143 of Set 3.0  | north platte
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=cayenne
# Processing Record 144 of Set 3.0  | cayenne
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=carutapera
# Processing Record 145 of Set 3.0  | carutapera
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=stornoway
# stornoway not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=hofn
# Processing Record 147 of Set 3.0  | hofn
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=labuhan
# Processing Record 148 of Set 3.0  | labuhan
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=hithadhoo
# Processing Record 149 of Set 3.0  | hithadhoo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=davila
# Processing Record 150 of Set 3.0  | davila
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sistranda
# Processing Record 151 of Set 3.0  | sistranda
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=promyshlennaya
# Processing Record 152 of Set 3.0  | promyshlennaya
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=puerto quijarro
# Processing Record 153 of Set 3.0  | puerto quijarro
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ahipara
# Processing Record 154 of Set 3.0  | ahipara
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=guerrero negro
# Processing Record 155 of Set 3.0  | guerrero negro
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=husavik
# Processing Record 156 of Set 3.0  | husavik
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=porbandar
# Processing Record 157 of Set 3.0  | porbandar
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=pevek
# Processing Record 158 of Set 3.0  | pevek
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=broome
# Processing Record 159 of Set 3.0  | broome
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=cabedelo
# Processing Record 160 of Set 3.0  | cabedelo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=saint simons
# Processing Record 161 of Set 3.0  | saint simons
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=suntar
# Processing Record 162 of Set 3.0  | suntar
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=zeya
# Processing Record 163 of Set 3.0  | zeya
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=teahupoo
# Processing Record 164 of Set 3.0  | teahupoo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=saint-philippe
# Processing Record 165 of Set 3.0  | saint-philippe
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=svetlaya
# Processing Record 166 of Set 3.0  | svetlaya
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=caledonia
# Processing Record 167 of Set 3.0  | caledonia
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=crab hill
# crab hill not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nizwa
# Processing Record 169 of Set 3.0  | nizwa
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=jalu
# Processing Record 170 of Set 3.0  | jalu
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=pangnirtung
# Processing Record 171 of Set 3.0  | pangnirtung
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=seoul
# Processing Record 172 of Set 3.0  | seoul
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=moose factory
# Processing Record 173 of Set 3.0  | moose factory
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=caucaia
# Processing Record 174 of Set 3.0  | caucaia
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=asau
# asau not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sept-iles
# Processing Record 176 of Set 4.0  | sept-iles
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ugoofaaru
# Processing Record 177 of Set 4.0  | ugoofaaru
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mutsamudu
# mutsamudu not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=henties bay
# Processing Record 179 of Set 4.0  | henties bay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=yumen
# Processing Record 180 of Set 4.0  | yumen
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=plettenberg bay
# Processing Record 181 of Set 4.0  | plettenberg bay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ribeira grande
# Processing Record 182 of Set 4.0  | ribeira grande
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=richards bay
# Processing Record 183 of Set 4.0  | richards bay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=illoqqortoormiut
# illoqqortoormiut not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=pisco
# Processing Record 185 of Set 4.0  | pisco
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=dubbo
# Processing Record 186 of Set 4.0  | dubbo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=trincomalee
# Processing Record 187 of Set 4.0  | trincomalee
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=muroto
# Processing Record 188 of Set 4.0  | muroto
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=narsaq
# Processing Record 189 of Set 4.0  | narsaq
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=cockburn town
# Processing Record 190 of Set 4.0  | cockburn town
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=batagay
# Processing Record 191 of Set 4.0  | batagay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=chicama
# Processing Record 192 of Set 4.0  | chicama
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bud
# Processing Record 193 of Set 4.0  | bud
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sao jose da coroa grande
# Processing Record 194 of Set 4.0  | sao jose da coroa grande
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=yellowknife
# Processing Record 195 of Set 4.0  | yellowknife
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=boone
# Processing Record 196 of Set 4.0  | boone
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=batticaloa
# Processing Record 197 of Set 4.0  | batticaloa
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ullapool
# Processing Record 198 of Set 4.0  | ullapool
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=pangai
# Processing Record 199 of Set 4.0  | pangai
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kaffrine
# Processing Record 200 of Set 4.0  | kaffrine
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=yulara
# Processing Record 201 of Set 4.0  | yulara
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=wainwright
# Processing Record 202 of Set 4.0  | wainwright
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=khatanga
# Processing Record 203 of Set 4.0  | khatanga
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=puerto del rosario
# Processing Record 204 of Set 4.0  | puerto del rosario
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=baykit
# Processing Record 205 of Set 4.0  | baykit
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=iracoubo
# Processing Record 206 of Set 4.0  | iracoubo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=fort nelson
# Processing Record 207 of Set 4.0  | fort nelson
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nazilli
# Processing Record 208 of Set 4.0  | nazilli
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=lakselv
# Processing Record 209 of Set 4.0  | lakselv
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kaeo
# Processing Record 210 of Set 4.0  | kaeo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kahului
# Processing Record 211 of Set 4.0  | kahului
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=vaitupu
# vaitupu not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=champerico
# Processing Record 213 of Set 4.0  | champerico
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=gornopravdinsk
# Processing Record 214 of Set 4.0  | gornopravdinsk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nguiu
# nguiu not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=conceicao da barra
# Processing Record 216 of Set 4.0  | conceicao da barra
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bibiani
# Processing Record 217 of Set 4.0  | bibiani
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nhulunbuy
# Processing Record 218 of Set 4.0  | nhulunbuy
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=rocha
# Processing Record 219 of Set 4.0  | rocha
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nuuk
# Processing Record 220 of Set 4.0  | nuuk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=marovoay
# Processing Record 221 of Set 4.0  | marovoay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=flin flon
# Processing Record 222 of Set 4.0  | flin flon
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sentyabrskiy
# sentyabrskiy not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nizhneyansk
# nizhneyansk not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mayumba
# Processing Record 225 of Set 4.0  | mayumba
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kathu
# Processing Record 226 of Set 5.0  | kathu
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tiksi
# Processing Record 227 of Set 5.0  | tiksi
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=puro
# Processing Record 228 of Set 5.0  | puro
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=urozhaynoye
# Processing Record 229 of Set 5.0  | urozhaynoye
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=banska stiavnica
# Processing Record 230 of Set 5.0  | banska stiavnica
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=grand river south east
# grand river south east not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mahebourg
# Processing Record 232 of Set 5.0  | mahebourg
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kodiak
# Processing Record 233 of Set 5.0  | kodiak
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=dzhusaly
# dzhusaly not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=omboue
# Processing Record 235 of Set 5.0  | omboue
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=anloga
# Processing Record 236 of Set 5.0  | anloga
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=marsaxlokk
# Processing Record 237 of Set 5.0  | marsaxlokk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=manggar
# Processing Record 238 of Set 5.0  | manggar
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=komsomolskiy
# Processing Record 239 of Set 5.0  | komsomolskiy
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=karratha
# Processing Record 240 of Set 5.0  | karratha
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=marsh harbour
# Processing Record 241 of Set 5.0  | marsh harbour
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=shingu
# Processing Record 242 of Set 5.0  | shingu
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=andenes
# andenes not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=itagiba
# Processing Record 244 of Set 5.0  | itagiba
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=westport
# Processing Record 245 of Set 5.0  | westport
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bratsk
# Processing Record 246 of Set 5.0  | bratsk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=erdenet
# Processing Record 247 of Set 5.0  | erdenet
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mocuba
# Processing Record 248 of Set 5.0  | mocuba
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sringeri
# Processing Record 249 of Set 5.0  | sringeri
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=huambo
# Processing Record 250 of Set 5.0  | huambo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=coquimbo
# Processing Record 251 of Set 5.0  | coquimbo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=porto velho
# Processing Record 252 of Set 5.0  | porto velho
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tuktoyaktuk
# Processing Record 253 of Set 5.0  | tuktoyaktuk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bamako
# Processing Record 254 of Set 5.0  | bamako
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=aljezur
# Processing Record 255 of Set 5.0  | aljezur
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=awjilah
# Processing Record 256 of Set 5.0  | awjilah
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=belaya gora
# Processing Record 257 of Set 5.0  | belaya gora
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tacoronte
# Processing Record 258 of Set 5.0  | tacoronte
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=albolote
# Processing Record 259 of Set 5.0  | albolote
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=port elizabeth
# Processing Record 260 of Set 5.0  | port elizabeth
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=chapais
# Processing Record 261 of Set 5.0  | chapais
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tuatapere
# Processing Record 262 of Set 5.0  | tuatapere
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=iskateley
# Processing Record 263 of Set 5.0  | iskateley
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=alice springs
# Processing Record 264 of Set 5.0  | alice springs
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=cidreira
# Processing Record 265 of Set 5.0  | cidreira
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sambava
# Processing Record 266 of Set 5.0  | sambava
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=outlook
# Processing Record 267 of Set 5.0  | outlook
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=eau claire
# Processing Record 268 of Set 5.0  | eau claire
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=pailon
# Processing Record 269 of Set 5.0  | pailon
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=upernavik
# Processing Record 270 of Set 5.0  | upernavik
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=flinders
# Processing Record 271 of Set 5.0  | flinders
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tutoia
# Processing Record 272 of Set 5.0  | tutoia
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=paamiut
# Processing Record 273 of Set 5.0  | paamiut
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=codrington
# Processing Record 274 of Set 5.0  | codrington
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=miles city
# Processing Record 275 of Set 6.0  | miles city
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=saleaula
# saleaula not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=college
# Processing Record 277 of Set 6.0  | college
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=marathon
# Processing Record 278 of Set 6.0  | marathon
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=nortelandia
# Processing Record 279 of Set 6.0  | nortelandia
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=vao
# Processing Record 280 of Set 6.0  | vao
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=fram
# Processing Record 281 of Set 6.0  | fram
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=pacific grove
# Processing Record 282 of Set 6.0  | pacific grove
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sola
# Processing Record 283 of Set 6.0  | sola
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=miri
# Processing Record 284 of Set 6.0  | miri
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ponta do sol
# Processing Record 285 of Set 6.0  | ponta do sol
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=cabo san lucas
# Processing Record 286 of Set 6.0  | cabo san lucas
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=muros
# Processing Record 287 of Set 6.0  | muros
# ...
# Processing Record 551 of Set 11.0  | ucluelet
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=rio grande
# Processing Record 552 of Set 11.0  | rio grande
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=huarmey
# Processing Record 553 of Set 11.0  | huarmey
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ankang
# Processing Record 554 of Set 11.0  | ankang
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=montego bay
# Processing Record 555 of Set 11.0  | montego bay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=morgan city
# Processing Record 556 of Set 11.0  | morgan city
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=saint-pierre
# Processing Record 557 of Set 11.0  | saint-pierre
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=iranshahr
# Processing Record 558 of Set 11.0  | iranshahr
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=halifax
# Processing Record 559 of Set 11.0  | halifax
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=miraflores
# Processing Record 560 of Set 11.0  | miraflores
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ola
# Processing Record 561 of Set 11.0  | ola
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=marv dasht
# marv dasht not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=morant bay
# Processing Record 563 of Set 11.0  | morant bay
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=olafsvik
# olafsvik not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kuah
# kuah not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ningxiang
# Processing Record 566 of Set 11.0  | ningxiang
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tilichiki
# Processing Record 567 of Set 11.0  | tilichiki
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kibala
# Processing Record 568 of Set 11.0  | kibala
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=maniitsoq
# Processing Record 569 of Set 11.0  | maniitsoq
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=tacuarembo
# Processing Record 570 of Set 11.0  | tacuarembo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=moiyabana
# moiyabana not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=port macquarie
# Processing Record 572 of Set 11.0  | port macquarie
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=chingirlau
# Processing Record 573 of Set 11.0  | chingirlau
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=lukang
# Processing Record 574 of Set 11.0  | lukang
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=oranjemund
# Processing Record 575 of Set 12.0  | oranjemund
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=coffs harbour
# Processing Record 576 of Set 12.0  | coffs harbour
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=anaconda
# Processing Record 577 of Set 12.0  | anaconda
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=marcona
# marcona not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=pangkalanbuun
# Processing Record 579 of Set 12.0  | pangkalanbuun
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=zavyalovo
# Processing Record 580 of Set 12.0  | zavyalovo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=klaksvik
# Processing Record 581 of Set 12.0  | klaksvik
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=panaba
# Processing Record 582 of Set 12.0  | panaba
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=teluknaga
# Processing Record 583 of Set 12.0  | teluknaga
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=oksbol
# Processing Record 584 of Set 12.0  | oksbol
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=calama
# Processing Record 585 of Set 12.0  | calama
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=komatipoort
# Processing Record 586 of Set 12.0  | komatipoort
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=wuzhou
# Processing Record 587 of Set 12.0  | wuzhou
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=rafai
# Processing Record 588 of Set 12.0  | rafai
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=urdzhar
# urdzhar not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=hay river
# Processing Record 590 of Set 12.0  | hay river
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kainantu
# Processing Record 591 of Set 12.0  | kainantu
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=harper
# Processing Record 592 of Set 12.0  | harper
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=talara
# Processing Record 593 of Set 12.0  | talara
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sao felix do xingu
# Processing Record 594 of Set 12.0  | sao felix do xingu
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=panalingaan
# Processing Record 595 of Set 12.0  | panalingaan
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=vredendal
# Processing Record 596 of Set 12.0  | vredendal
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=malegaon
# Processing Record 597 of Set 12.0  | malegaon
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=finnsnes
# Processing Record 598 of Set 12.0  | finnsnes
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ondorhaan
# ondorhaan not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=gat
# Processing Record 600 of Set 12.0  | gat
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=yaan
# Processing Record 601 of Set 12.0  | yaan
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=juba
# Processing Record 602 of Set 12.0  | juba
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=mountain home
# Processing Record 603 of Set 12.0  | mountain home
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=sawakin
# Processing Record 604 of Set 12.0  | sawakin
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=urdoma
# Processing Record 605 of Set 12.0  | urdoma
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=aleksandrovskiy zavod
# Processing Record 606 of Set 12.0  | aleksandrovskiy zavod
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=bur gabo
# bur gabo not found.Skipping ...
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=beaumont
# Processing Record 608 of Set 12.0  | beaumont
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=el campo
# Processing Record 609 of Set 12.0  | el campo
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=havre-saint-pierre
# Processing Record 610 of Set 12.0  | havre-saint-pierre
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=coxim
# Processing Record 611 of Set 12.0  | coxim
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kenai
# Processing Record 612 of Set 12.0  | kenai
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=lukashin
# Processing Record 613 of Set 12.0  | lukashin
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=kutum
# Processing Record 614 of Set 12.0  | kutum
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=port-gentil
# Processing Record 615 of Set 12.0  | port-gentil
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=okhotsk
# Processing Record 616 of Set 12.0  | okhotsk
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=ciudad bolivar
# Processing Record 617 of Set 12.0  | ciudad bolivar
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=saldanha
# Processing Record 618 of Set 12.0  | saldanha
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=floresta
# Processing Record 619 of Set 12.0  | floresta
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=levelland
# Processing Record 620 of Set 12.0  | levelland
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=russellville
# Processing Record 621 of Set 12.0  | russellville
# target_url= http://api.openweathermap.org/data/2.5/weather?appid=aabe9dcdafb0dc3a3c51e7df52e100d1&units=metric&q=dabakala
# Processing Record 622 of Set 12.0  | dabakala
# cities length 623
# ['taolanaro', 'jamestown', 'sao filipe', 'geraldton', 'east london', 'atuona', 'airai', 'belushya guba', 'punta arenas', 'kruisfontein', 'tsihombe', 'svetlogorsk', 'darnah', 'torbay', 'busselton', 'touros', 'zhicheng', 'rikitea', 'awbari', 'montepuez', 'port alfred', 'ilulissat', 'bredasdorp', 'iisalmi', 'kaitangata', 'ayorou', 'mehamn', 'bengkulu', 'duvan', 'muzhi', 'port hardy', 'bandarbeyla', 'lebu', 'longyearbyen', 'ushuaia', 'lagoa', 'seeboden', 'mutoko', 'khorixas', 'avarua', 'toamasina', 'soavinandriana', 'mar del plata', 'nakonde', 'san patricio', 'barrow', 'vaini', 'kholodnyy', 'meadow lake', 'severo-kurilsk', 'nemuro', 'half moon bay', 'kapaa', 'santa rosa', 'tasiilaq', 'isangel', 'cherskiy', 'port pirie', 'hobart', 'shyryayeve', 'umm bab', 'saint-augustin', 'hilo', 'skibbereen', 'souillac', 'thompson', 'alugan', 'puerto ayora', 'albany', 'vardo', 'shubarkuduk', 'barentsburg', 'butaritari', 'kavaratti', 'naze', 'atar', 'saint george', 'georgetown', 'new norfolk', 'dikson', 'yemelyanovo', 'douentza', 'coruripe', 'staryy krym', 'saskylakh', 'cape town', 'mataura', 'mys shmidta', 'general roca', 'bethel', 'copiapo', 'batemans bay', 'ushtobe', 'bambanglipuro', 'santa cruz', 'ust-maya', 'taywarah', 'quirinopolis', 'kindersley', 'vanimo', 'rawson', 'mirabad', 'esperance', 'znamenskoye', 'castro', 'takob', 'sao jose do campestre', 'tabiauea', 'katsuura', 'norman wells', 'hermanus', 'qaanaaq', 'balimo', 'clyde river', 'constitucion', 'provideniya', 'samusu', 'kamenskoye', 'molodizhne', 'rio gallegos', 'chokurdakh', 'paracuru', 'zaysan', 'krasnoselkup', 'luderitz', 'felidhoo', 'biak', 'imbituba', 'banmo', 'alotau', 'tessalit', 'hun', 'fortuna', 'sao joao da barra', 'isla vista', 'nantucket', 'victor harbor', 'ancud', 'kavieng', 'laguna', 'arraial do cabo', 'bluff', 'urengoy', 'north platte', 'cayenne', 'carutapera', 'stornoway', 'hofn', 'labuhan', 'hithadhoo', 'davila', 'sistranda', 'promyshlennaya', 'puerto quijarro', 'ahipara', 'guerrero negro', 'husavik', 'porbandar', 'pevek', 'broome', 'cabedelo', 'saint simons', 'suntar', 'zeya', 'teahupoo', 'saint-philippe', 'svetlaya', 'caledonia', 'crab hill', 'nizwa', 'jalu', 'pangnirtung', 'seoul', 'moose factory', 'caucaia', 'asau', 'sept-iles', 'ugoofaaru', 'mutsamudu', 'henties bay', 'yumen', 'plettenberg bay', 'ribeira grande', 'richards bay', 'illoqqortoormiut', 'pisco', 'dubbo', 'trincomalee', 'muroto', 'narsaq', 'cockburn town', 'batagay', 'chicama', 'bud', 'sao jose da coroa grande', 'yellowknife', 'boone', 'batticaloa', 'ullapool', 'pangai', 'kaffrine', 'yulara', 'wainwright', 'khatanga', 'puerto del rosario', 'baykit', 'iracoubo', 'fort nelson', 'nazilli', 'lakselv', 'kaeo', 'kahului', 'vaitupu', 'champerico', 'gornopravdinsk', 'nguiu', 'conceicao da barra', 'bibiani', 'nhulunbuy', 'rocha', 'nuuk', 'marovoay', 'flin flon', 'sentyabrskiy', 'nizhneyansk', 'mayumba', 'kathu', 'tiksi', 'puro', 'urozhaynoye', 'banska stiavnica', 'grand river south east', 'mahebourg', 'kodiak', 'dzhusaly', 'omboue', 'anloga', 'marsaxlokk', 'manggar', 'komsomolskiy', 'karratha', 'marsh harbour', 'shingu', 'andenes', 'itagiba', 'westport', 'bratsk', 'erdenet', 'mocuba', 'sringeri', 'huambo', 'coquimbo', 'porto velho', 'tuktoyaktuk', 'bamako', 'aljezur', 'awjilah', 'belaya gora', 'tacoronte', 'albolote', 'port elizabeth', 'chapais', 'tuatapere', 'iskateley', 'alice springs', 'cidreira', 'sambava', 'outlook', 'eau claire', 'pailon', 'upernavik', 'flinders', 'tutoia', 'paamiut', 'codrington', 'miles city', 'saleaula', 'college', 'marathon', 'nortelandia', 'vao', 'fram', 'pacific grove', 'sola', 'miri', 'ponta do sol', 'cabo san lucas', 'muros', 'praia', 'carnarvon', 'iquique', 'daru', 'strelka', 'dauriya', 'kjopsvik', 'iqaluit', 'huron', 'nicoya', 'tobol', 'temiscaming', 'griffith', 'san cristobal', 'durban', 'bardiyah', 'muscatine', 'elat', 'marystown', 'chuy', 'beloha', 'belmonte', 'bathsheba', 'ust-kamchatsk', 'kamenka', 'nome', 'lima', 'taoudenni', 'jibuti', 'varkaus', 'kisangani', 'talnakh', 'ch ...

# %%
###########################################################################################
### Everything is in a file and read  it to perform calculations.
##########################################################################################
#read the JSON file and make a dict or dataframe 
with open('api_response.json') as json_file:  
    weather_data = json.load(json_file)
#print(weather_data)    

###########################################################################################
#df = pd.DataFrame.from_dict(json_normalize(data), orient='columns') -- json to dataframe for nested dict

weather_datadf=pd.DataFrame.from_dict(json_normalize(weather_data), orient='columns')

###########################################################################################
## Printing columns to understand the data better for plotting
for col in weather_datadf.columns:
    print(col)
###########################################################################################   
#### Insert a column in the dataframe called cities - from cities list- not needed really the balue is already there as
### 'name' but this will let me check if the lat and longs are correct
###########################################################################################
column_values = pd.Series(cities)
weather_datadf.insert(loc=0, column='cities', value=column_values)

##Testing if the cities and their co-ordinates are correct.
#print(weather_datadf[['sys.country', 'coord.lat', 'coord.lon', 'cities']])
###########################################################################################
## Igonore the code below **********
###########################################################################################
# print(cities)
# weather_datadf['Cities']=cities

# weather_datadf.describe()

#print(weather_datadf['coord.lat'])
# latitude.append(response['coord']['lat'])
# longitude.append(response['coord']['lon'])
# temperature.append(response['main']['temp'])
# humidity.append(response['main']['humidity'])
# cloudiness.append(response['clouds']['all'])
# windspeed.append(response['wind']['speed'])
# country.append(response['sys']['country'])
# max_temp.append(response['main']['temp_max'])
# date.append(response['dt'])
# Out:
# base
# clouds.all
# cod
# coord.lat
# coord.lon
# dt
# id
# main.grnd_level
# main.humidity
# main.pressure
# main.sea_level
# main.temp
# main.temp_max
# main.temp_min
# message
# name
# rain.1h
# rain.3h
# sys.country
# sys.id
# sys.message
# sys.sunrise
# sys.sunset
# sys.type
# timezone
# visibility
# weather
# wind.deg
# wind.gust
# wind.speed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
###DataFrame.to_csv(path_or_buf=None, sep=', ', na_rep='', float_format=None, columns=None, header=True, 
###index=True, index_label=None, mode='w', encoding=None, compression='infer', quoting=None, quotechar='"', 
###line_terminator=None, chunksize=None, tupleize_cols=None, date_format=None, doublequote=True, escapechar=None,
###decimal='.')[source]
   
newweatherdf=weather_datadf[['cities','clouds.all','sys.country','dt','main.humidity','coord.lat','coord.lon','main.temp_max','wind.speed']]


from datetime import date
newweatherdf['dt'] = pd.to_datetime(newweatherdf['dt'],unit='s') 
newweatherdf=newweatherdf.dropna(thresh=2)
newweatherdf.rename(columns = {'cities':'City','clouds.all':'Cloudiness', 'sys.country':'Country', 'dt':'Date',
                              'main.humidity':'Humidity','coord.lat':'Latitude' , 'coord.lon': 'Longitude',
                              'main.temp_max':'MaxTemperature', 'wind.speed':'WindSpeed'}, inplace = True)

with open("weather_data.csv", mode='w',newline='') as datafile: 
    newweatherdf.to_csv(path_or_buf=datafile, index=True)
    
newweatherdf.head(20)

###### IGNORE the caveats ****
# Out:
# C:\Users\divya\Anaconda3\envs\pythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#             City  Cloudiness Country                Date  Humidity  Latitude  \
# 1      jamestown         1.0      AU 2019-07-02 23:14:28      85.0    -33.21
# 2     sao filipe        97.0      CV 2019-07-02 23:14:28      81.0     14.90
# 3      geraldton        75.0      CA 2019-07-02 23:14:15      32.0     49.72
# 4    east london        46.0      ZA 2019-07-02 23:14:29      33.0    -33.02
# 5         atuona         5.0      PF 2019-07-02 23:14:29      78.0     -9.80
# 6          airai        80.0      TL 2019-07-02 23:14:29      60.0     -8.93
# 8   punta arenas        90.0      CL 2019-07-02 23:14:29      92.0    -53.16
# 9   kruisfontein        54.0      ZA 2019-07-02 23:12:33      56.0    -34.00
# 11   svetlogorsk        90.0      RU 2019-07-02 23:14:30     100.0     53.14
# 12        darnah         0.0      LY 2019-07-02 23:14:30      77.0     32.77
# 13        torbay        90.0      CA 2019-07-02 23:14:30      93.0     47.66
# 14     busselton         5.0      AU 2019-07-02 23:14:30      78.0    -33.64
# 15        touros        42.0      BR 2019-07-02 23:14:30      80.0     -5.20
# 16      zhicheng        41.0      CN 2019-07-02 23:14:31      42.0     35.04
# 17       rikitea       100.0      PF 2019-07-02 23:06:25      87.0    -23.12
# 18        awbari         0.0      LY 2019-07-02 23:14:31      20.0     26.59
# 19     montepuez         2.0      MZ 2019-07-02 23:14:31      90.0    -13.13
# 20   port alfred        61.0      ZA 2019-07-02 23:14:31      46.0    -33.59
# 21     ilulissat        75.0      GL 2019-07-02 23:14:31      35.0     69.22
# 22    bredasdorp        67.0      ZA 2019-07-02 23:12:55      59.0    -34.53
#
#     Longitude  MaxTemperature  WindSpeed
# 1      138.60           10.99       5.15
# 2      -24.50           23.19       7.94
# 3      -86.95           28.00       3.10
# 4       27.91           15.29       4.30
# 5     -139.03           26.79       5.85
# 6      125.41           25.29       1.17
# 8      -70.91            1.00       5.10
# 9       24.73           14.49       3.57
# 11      59.15           14.00       1.37
# 12      22.64           24.59       3.17
# 13     -52.73           15.00       5.70
# 14     115.35            6.11       8.36
# 15     -35.46           26.59       5.95
# 16     112.59           27.59       3.01
# 17    -134.97           19.29      10.86
# 18      12.77           28.79       3.59
# 19      39.00           17.39       1.04
# 20      26.89           20.00       1.79
# 21     -51.10           13.00       6.20
# 22      20.04           17.78       6.70

# %%
newweatherdf.count()
# Out:
# City              566
# Cloudiness        566
# Country           566
# Date              566
# Humidity          566
# Latitude          566
# Longitude         566
# MaxTemperature    566
# WindSpeed         566
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import date

plt.figure(figsize=(10, 7), dpi=80)
maxtemperature=weather_datadf['main.temp_max']
latitude=weather_datadf['coord.lat']

plt.scatter(latitude, maxtemperature,  marker="o", 
                       facecolors="coral", edgecolors="black",label = "Suburban", alpha=0.80, linewidths=1)

##### Get today's date in the title ##################
da=date.today()
title="City latitude Vs. Max Temperature(" + str(da) +")"
#print("title=", title)
plt.title(title)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("Divya_Scatter_lat_maxtemp.png", transparent=False, bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
from datetime import date

plt.figure(figsize=(10, 7), dpi=80)
humidity=weather_datadf['main.humidity']
latitude=weather_datadf['coord.lat']
plt.ylim(10, 110)
#plt.yticks(20, 100, 20)

plt.scatter(latitude, humidity,  marker="o", 
                       facecolors="gold", edgecolors="black",label = "Suburban", alpha=0.80, linewidths=1)

##### Get today's date in the title ##################
da=date.today()
title="City latitude Vs. Humidity(" + str(da) +")"
#print("title=", title)
plt.title(title)
#plt.title("City latitude Vs. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)
plt.savefig("Divya_Scatter_lat_humidity.png", transparent=False, bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
from datetime import date

plt.figure(figsize=(10, 7), dpi=80)
cloudiness=weather_datadf['clouds.all']
latitude=weather_datadf['coord.lat']

plt.scatter(latitude, cloudiness,  marker="o", 
                       facecolors="skyblue", edgecolors="black",label = "Suburban", alpha=0.80, linewidths=1)


##### Get today's date in the title ##################
da=date.today()
title="City latitude Vs. Cloudiness(" + str(da) +")"
#print("title=", title)
plt.title(title)

#plt.title("City latitude Vs. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)
plt.savefig("Divya_Scatter_lat_cloudiness.png", transparent=False, bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
from datetime import date

plt.figure(figsize=(10, 7), dpi=80)
windspeed=weather_datadf['wind.speed']
latitude=weather_datadf['coord.lat']

plt.scatter(latitude, windspeed,  marker="o", 
                       facecolors="blue", edgecolors="black",label = "Suburban", alpha=0.80, linewidths=1)

##### Get today's date in the title ##################
da=date.today()
title="City latitude Vs. Wind Speed(" + str(da) +")"
#print("title=", title)
plt.title(title)
#plt.title("City latitude Vs. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("Divya_Scatter_lat_windspeed.png", transparent=False, bbox_inches="tight")
